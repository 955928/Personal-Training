# %%
#créer une fonction graphique qui permet de tracer plusieurs graphiques sur une figure
#corréspondant à des données récoltés dans plusiuers expériences

import numpy as np

# %%
dataset = {f"experience{i}": np.random.randn(100) for i in range (4)}
dataset
# Out:
# {'experience0': array([-0.20397172, -0.01029816, -0.6471789 , -0.54938897, -0.58987973,
#         -0.50538233,  0.61530624, -0.74780362, -0.82072931, -0.44632173,
#         -0.64754837,  0.22852692, -0.0199071 ,  0.11690096, -0.19616034,
#          1.06984059, -1.14853087,  2.4546065 , -0.24206332, -1.33369906,
#          0.21015527,  0.36326113, -0.73913143,  0.81140622, -0.53867401,
#         -0.59046012, -0.11154001, -0.73831385, -0.22883376, -1.29684608,
#          0.74931013,  1.0769902 ,  0.40030434, -1.40798209,  1.16125025,
#         -2.01754606,  0.52805033, -0.45630437, -0.7170674 , -0.56661568,
#          0.63950827,  0.66517067, -0.07648447, -0.22895599,  0.63536952,
#          0.47520952,  0.61696125, -1.26372774, -0.10494913, -0.65398647,
#          0.86358261, -0.27362005,  0.71165376, -2.86783992,  0.39102066,
#         -2.13034737,  0.30505004, -1.03713062, -0.58860234, -0.30163917,
#          1.07029264, -2.34471494, -2.65029009, -1.53234544, -0.13342791,
# ...

# %%
dataset_ = list[dataset]
dataset_
# Out:
# list[{'experience0': array([-0.20397172, -0.01029816, -0.6471789 , -0.54938897, -0.58987973,
#        -0.50538233,  0.61530624, -0.74780362, -0.82072931, -0.44632173,
#        -0.64754837,  0.22852692, -0.0199071 ,  0.11690096, -0.19616034,
#         1.06984059, -1.14853087,  2.4546065 , -0.24206332, -1.33369906,
#         0.21015527,  0.36326113, -0.73913143,  0.81140622, -0.53867401,
#        -0.59046012, -0.11154001, -0.73831385, -0.22883376, -1.29684608,
#         0.74931013,  1.0769902 ,  0.40030434, -1.40798209,  1.16125025,
#        -2.01754606,  0.52805033, -0.45630437, -0.7170674 , -0.56661568,
#         0.63950827,  0.66517067, -0.07648447, -0.22895599,  0.63536952,
#         0.47520952,  0.61696125, -1.26372774, -0.10494913, -0.65398647,
#         0.86358261, -0.27362005,  0.71165376, -2.86783992,  0.39102066,
#        -2.13034737,  0.30505004, -1.03713062, -0.58860234, -0.30163917,
#         1.07029264, -2.34471494, -2.65029009, -1.53234544, -0.13342791,
# ...

# %%
import numpy as np
import matplotlib as plt

def graphique(dataset_):
    for i in range (4):
        plt.figure(24, 4, 1)
        plt.plot(x, y, c="red")
        plt.title("Experience {i}")
        plt.figure(24, 4, 2)
        plt.plot(x, y, c="yellow")
        plt.title("Experience {i}")
        plt.figure(24, 4, 3)
        plt.plot(x, y, c="green")
        plt.title("Experience {i}")
        plt.figure(24, 4, 4)
        plt.plot(x, y, c="blue")
        plt.title("Experience {i}")
        return i

# %%
type(dataset_)
# Out:
# types.GenericAlias

# %%
dataset_(graphique)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dataset_(graphique)
#
# TypeError: 'function' object is not iterable

# %%
#REPONSE
import numpy as np
import matplotlib.pyplot as plt

dataset = {f"experience{i}": np.random.randn(100) for i in range (4)}

# %%
def graphique(data):
    n = len(data)
    plt.figure(figsize=(12, 20))
    
    for k, i in zip(data.keys(), range(1, n+1)):
        plt.subplot(n, 1, i)
        plt.plot(data[k])
        plt.title(k)
        
    plt.show()

# %%
graphique(dataset)

# %%
dataset = {f"experience{i}": np.random.randn(100, 3) for i in range (4)}
#3 variable différent

# %%
graphique(dataset)
