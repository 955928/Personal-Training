# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import random

# %%
""""
my attempt at Wa-TOR lol
class Planet:
    def Wa_Tor(self,length, height, fish_time_reproduction):
    self.length = 
    self.height = 

class Fish:
    
    def fish_time_reproduction(self,reproduce):
    self
    
class Shark(Fish):
    
    def shark_time_reproduction(fish_time_reproduction):
    self
# Out:
#   Cell In[65], line 1
#     """"
#     ^
# SyntaxError: incomplete input

# %%
#Proposé par Chat Gpt

# %%
""
""
class Planet:
    def __init__(self, largeur, hauteur, fish_time_reproduction, shark_time_reproduction, energie):
        self.largeur = 100
        self.hauteur = 70
        self.fish_time_reproduction = fish_time_reproduction
        self.shark_time_reproduction = shark_time_reproduction
        self.energie = energie
        self.grid = [['empty' for largeur in range(100)] for hauteur in range(70)]   
    
    def initialise_entities(self, num_fishes, num_sharks):
        # Placez aléatoirement des poissons et des requins sur la grille
        # Assurez-vous que chaque case est vide avant de placer une entité
        for fish in range(num_fishes):
            x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            while self.grid[x][y] != 'empty':
                x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            self.grid[x][y] = Poisson(self, x, y)

        for shark in range(num_sharks):
            x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            while self.grid[x][y] != 'empty':
                x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            self.grid[x][y] = Requin(self, x, y, self.energie)

    def simuler_chronon(self):
        for row in self.grid:
            for entity in row:
                if entity != 'empty':
                    entity.agir()

class Entite:
    def __init__(self, planet, x, y):
        self.planet = planet
        self.x = x
        self.y = y
        self.age = 0

    def move(self, new_x, new_y):
        # Logique de déplacement en tenant compte des règles toroïdales
        # Mettez à jour les coordonnées de l'entité après le déplacement
        pass

    def reproduce(self):
        # Logique de reproduction
        if self.age >= self.temps_reproduction:
            cases_voisines = self.get_voisins()  # Obtient les coordonnées des cases voisines
            cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']

            if cases_libres:
                nouvelle_position = random.choice(cases_libres)
                self.planet.grid[nouvelle_position[0]][nouvelle_position[1]] = type(self)(self.planet, *nouvelle_position)  # Crée une nouvelle entité de même type
                self.age = 0  # Réinitialise l'âge après la reproduction

    def action(self):
          # Logique générale pour chaque entité à chaque chronon
        self.age += 1  # Incrémente l'âge de l'entité à chaque chronon
        self.reproduce()  # Vérifie si l'entité peut se reproduire
        self.move()  # Déplace l'entité
        self.action()  # Effectue une action spécifique à l'entité

class Fish(Entite):
    def choose_new_position(self, cases_voisines):
        # Choix aléatoire d'une case voisine libre
        cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']
        if cases_libres:
            return random.choice(cases_libres)
        else:
            return None

class Shark(Entite):
    def __init__(self, planete, x, y, energie):
        super().__init__(planete, x, y)
        self.energie = energie

    def choose_nouvelle_position(self, cases_voisines):
        # Choix de la nouvelle position pour chasser et manger un poisson
        poissons_proches = [case for case in cases_voisines if isinstance(self.planet.grid[case[0]][case[1]], Poisson)]

        if poissons_proches:
            poisson_cible = random.choice(poissons_proches)
            return poisson_cible
        else:
            # Si aucun poisson n'est à proximité, choisir une case voisine libre
            cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']
            if cases_libres:
                return random.choice(cases_libres)
            else:
                return None

# %%
#my research using chat gpt in order to assemble  different section of codes proposed by Chat GpT
""""
class Planet:
    def __init__(self, largeur, hauteur, fish_time_reproduction, shark_time_reproduction, energie):
        self.largeur = 100
        self.hauteur = 70
        self.fish_time_reproduction = fish_time_reproduction
        self.shark_time_reproduction = shark_time_reproduction
        self.energie = energie
        self.grid = [['empty' for largeur in range(100)] for hauteur in range(70)]   
    
    def initialise_entities(self, num_fishes, num_sharks):

        for fish in range(num_fishes):
            x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            while self.grid[x][y] != 'empty':
                x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            self.grid[x][y] = Poisson(self, x, y)

        for shark in range(num_sharks):
            x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            while self.grid[x][y] != 'empty':
                x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            self.grid[x][y] = Requin(self, x, y, self.energie)

    def simuler_chronon(self):
        for row in self.grid:
            for entity in row:
                if entity != 'empty':
                    entity.agir()

class Entite:
    def __init__(self, planet, x, y):
        self.planet = planet
        self.x = x
        self.y = y
        self.age = 0

    def move(self, new_x, new_y):
        cases_voisines = self.get_voisins()
        nouvelle_position = self.choose_nouvelle_position(cases_voisines)

        if nouvelle_position:
            self.se_deplacer(*nouvelle_position)

    def reproduce(self):
        if self.age >= self.temps_reproduction:
            cases_voisines = self.get_voisins() 
            cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']

            if cases_libres:
                nouvelle_position = random.choice(cases_libres)
                self.planet.grid[nouvelle_position[0]][nouvelle_position[1]] = type(self)(self.planet, *nouvelle_position)  # Crée une nouvelle entité de même type
                self.age = 0  
    def action(self):
          
        self.age += 1 
        self.reproduce() 
        self.move()  
        self.action() 

class Fish(Entite):
    def choose_new_position(self, cases_voisines):
        
        cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']
        if cases_libres:
            return random.choice(cases_libres)
        else:
            return None

class Shark(Entite):
    def __init__(self, planete, x, y, energie):
        super().__init__(planete, x, y)
        self.energie = energie

    def choose_nouvelle_position(self, cases_voisines):
       
        poissons_proches = [case for case in cases_voisines if isinstance(self.planet.grid[case[0]][case[1]], Poisson)]

        if poissons_proches:
            poisson_cible = random.choice(poissons_proches)
            return poisson_cible
        else:
            
            cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']
            if cases_libres:
                return random.choice(cases_libres)
            else:
                return None
# Out:
#   Cell In[68], line 2
#     """"
#     ^
# SyntaxError: incomplete input

# %%
#Correction proposed by chat GPT of the preceding program
""""
import random

class Planet:
    def __init__(self, largeur, hauteur, fish_time_reproduction, shark_time_reproduction, energie):
        self.largeur = largeur
        self.hauteur = hauteur
        self.fish_time_reproduction = fish_time_reproduction
        self.shark_time_reproduction = shark_time_reproduction
        self.energie = energie
        self.grid = [['empty' for _ in range(largeur)] for _ in range(hauteur)]

    def initialise_entities(self, num_fishes, num_sharks):
        for fish in range(num_fishes):
            x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            while self.grid[y][x] != 'empty':
                x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            self.grid[y][x] = Fish(self, x, y)

        for shark in range(num_sharks):
            x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            while self.grid[y][x] != 'empty':
                x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            self.grid[y][x] = Shark(self, x, y, self.energie)

    def simuler_chronon(self):
        for row in self.grid:
            for entity in row:
                if entity != 'empty':
                    entity.action()

class Entite:
    def __init__(self, planet, x, y):
        self.planet = planet
        self.x = x
        self.y = y
        self.age = 0
        self.temps_reproduction = 0  # Placeholder for the reproduction time; adjust as needed

    def move(self):
        cases_voisines = self.get_voisins()
        nouvelle_position = self.choose_nouvelle_position(cases_voisines)

        if nouvelle_position:
            self.se_deplacer(*nouvelle_position)

    def reproduce(self):
        if self.age >= self.temps_reproduction:
            cases_voisines = self.get_voisins()
            cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']

            if cases_libres:
                nouvelle_position = random.choice(cases_libres)
                self.planet.grid[nouvelle_position[0]][nouvelle_position[1]] = type(self)(self.planet, *nouvelle_position)
                self.age = 0

    def action(self):
        self.age += 1
        self.reproduce()
        self.move()

    def get_voisins(self):
        def get_voisins(self):
        voisins = []
        for i in range(-1, 2):
            for j in range(-1, 2):
                if i == 0 and j == 0:
                    continue  # Skip the current cell (self)
                
                x_neighbor = (self.x + i) % self.planet.largeur
                y_neighbor = (self.y + j) % self.planet.hauteur
                voisins.append((x_neighbor, y_neighbor))

        return voisins

    def choose_nouvelle_position(self, cases_voisines):
        cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']

        if cases_libres:
            return random.choice(cases_libres)
        else:
            return None

    def se_deplacer(self, new_x, new_y):
         def se_deplacer(self, new_x, new_y):
        # Ensure toroidal wrapping for x-coordinate
        self.x = (new_x + self.planet.largeur) % self.planet.largeur

        # Ensure toroidal wrapping for y-coordinate
        self.y = (new_y + self.planet.hauteur) % self.planet.hauteur

class Fish(Entite):
    def choose_nouvelle_position(self, cases_voisines):
        cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']
        if cases_libres:
            return random.choice(cases_libres)
        else:
            return None

class Shark(Entite):
    def __init__(self, planet, x, y, energie):
        super().__init__(planet, x, y)
        self.energie = energie

    def choose_nouvelle_position(self, cases_voisines):
        poissons_proches = [case for case in cases_voisines if isinstance(self.planet.grid[case[0]][case[1]], Fish)]

        if poissons_proches:
            poisson_cible = random.choice(poissons_proches)
            return poisson_cible
        else:
            cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']
            if cases_libres:
                return random.choice(cases_libres)
            else:
                return None
# Out:
#   Cell In[69], line 2
#     """"
#     ^
# SyntaxError: incomplete input

# %%
#Final correction by Chat Gpt with all of the missing programs

import random

class Planet:
    
    def __init__(self, largeur, hauteur, fish_time_reproduction, shark_time_reproduction, energie):
        self.largeur = largeur
        self.hauteur = hauteur
        self.fish_time_reproduction = fish_time_reproduction
        self.shark_time_reproduction = shark_time_reproduction
        self.energie = energie
        self.grid = [['empty' for _ in range(largeur)] for _ in range(hauteur)]

    def initialise_entities(self, num_fishes, num_sharks):
        for fish in range(num_fishes):
            x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            while self.grid[y][x] != 'empty':
                x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            self.grid[y][x] = Fish(self, x, y)
    
        for shark in range(num_sharks): 
            x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)
            while self.grid[y][x] != 'empty':
                x, y = random.randint(0, self.largeur - 1), random.randint(0, self.hauteur - 1)  
            self.grid[y][x] = Shark(self, x, y, energie=100)
       
  

    def simuler_chronon(self):
        for row in self.grid:
            for entity in row:
                if entity != 'empty':
                    entity.action()

    def visualiser(self):
        cmap = mcolors.ListedColormap(['blue', 'red', 'white'])
        boundaries = [-0.5, 0.5, 1.5, 2.5]
        norm = mcolors.BoundaryNorm(boundaries, cmap.N, clip=True)

        entity_grid = [[entity.get_type() if entity != 'empty' else 'empty' for entity in row] for row in self.grid]

        plt.imshow(entity_grid, interpolation='none', cmap=cmap, norm=norm)
        plt.title('Wa-Tor Simulation')
        plt.colorbar(ticks=[0, 1, 2], label='Entities')
        plt.show()

class Entite:
    def __init__(self, planet, x, y):
        self.planet = planet
        self.x = x
        self.y = y
        self.age = 0
        self.temps_reproduction = 0  # Placeholder for the reproduction time; adjust as needed

    def move(self):
        cases_voisines = self.get_voisins()
        nouvelle_position = self.choose_nouvelle_position(cases_voisines)

        if nouvelle_position:
            self.se_deplacer(*nouvelle_position)

    def reproduce(self):
        if self.age >= self.temps_reproduction:
            cases_voisines = self.get_voisins()
            cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']

            if cases_libres:
                nouvelle_position = random.choice(cases_libres)
                self.planet.grid[nouvelle_position[0]][nouvelle_position[1]] = type(self)(self.planet, *nouvelle_position)
                self.age = 0

    def action(self):
        self.age += 1
        self.reproduce()
        self.move()

    def get_voisins(self):
        voisins = []
        for i in range(-1, 2):
            for j in range(-1, 2):
                if i == 0 and j == 0:
                    continue  # Skip the current cell (self)

                x_neighbor = (self.x + i) % self.planet.largeur
                y_neighbor = (self.y + j) % self.planet.hauteur
                voisins.append((x_neighbor, y_neighbor))

        return voisins

    def choose_nouvelle_position(self, cases_voisines):
        cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']

        if cases_libres:
            return random.choice(cases_libres)
        else:
            return None

    def se_deplacer(self, new_x, new_y):
        # Ensure toroidal wrapping for x-coordinate
        self.x = (new_x + self.planet.largeur) % self.planet.largeur

        # Ensure toroidal wrapping for y-coordinate
        self.y = (new_y + self.planet.hauteur) % self.planet.hauteur

    def get_type(self):
        return 'empty'

class Fish(Entite):
    def choose_nouvelle_position(self, cases_voisines):
        cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']
        if cases_libres:
            return random.choice(cases_libres)
        else:
            return None

    def get_type(self):
        return 'fish'

class Shark(Entite):
    def __init__(self, planet, x, y, energie):
        super().__init__(planet, x, y)
        self.energie = energie


    def choose_nouvelle_position(self, cases_voisines):
        poissons_proches = [case for case in cases_voisines if isinstance(self.planet.grid[case[0]][case[1]], Fish)]

        if poissons_proches:
            poisson_cible = random.choice(poissons_proches)
            return poisson_cible
        else:
            cases_libres = [case for case in cases_voisines if self.planet.grid[case[0]][case[1]] == 'empty']
            if cases_libres:
                return random.choice(cases_libres)
            else:
                return None

    def get_type(self):
        return 'shark'

# %%
# Example usage:
planet = Planet(largeur=10, hauteur=10, fish_time_reproduction=3, shark_time_reproduction=4, energie=10)
planet.initialise_entities(num_fishes=5, num_sharks=3)

# Simulate and visualize for 10 time steps
for _ in range(10):
    planet.simuler_chronon()
    planet.visualiser()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 7
#       5 # Simulate and visualize for 10 time steps
#       6 for _ in range(10):
# ----> 7     planet.simuler_chronon()
#       8     planet.visualiser()
#
# Cell In[80], line 34, in Planet.simuler_chronon(self)
#      32 for entity in row:
#      33     if entity != 'empty':
# ---> 34         entity.action()
#
# Cell In[80], line 75, in Entite.action(self)
#      73 def action(self):
#      74     self.age += 1
# ---> 75     self.reproduce()
#      76     self.move()
#
# Cell In[80], line 70, in Entite.reproduce(self)
#      68 if cases_libres:
#      69     nouvelle_position = random.choice(cases_libres)
# ---> 70     self.planet.grid[nouvelle_position[0]][nouvelle_position[1]] = type(self)(self.planet, *nouvelle_position)
#      71     self.age = 0
#
# ...
